# %%
from sklearn.datasets import load_diabetes
# Load the data
X, y = load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
# The data given by sklearn has already been scaled and preprocessed.
df1 = pd.DataFrame(X, columns=['age', 'sex', 'bmi', 'bp', 'tc', 'ldl', 'hdl', 'tch', 'ltg', 'glu'])
print(df1)
# Out:
#           age       sex       bmi        bp        tc       ldl       hdl  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#           tch       ltg       glu
# 0   -0.002592  0.019908 -0.017646
# 1   -0.039493 -0.068330 -0.092204
# 2   -0.002592  0.002864 -0.025930
# 3    0.034309  0.022692 -0.009362
# 4   -0.002592 -0.031991 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018118  0.044485
# 439 -0.011080 -0.046879  0.015491
# 440  0.026560  0.044528 -0.025930
# 441 -0.039493 -0.004220  0.003064
#
# [442 rows x 10 columns]

# %%
df2 = pd.DataFrame(y, columns=['disease_progression'])
print(df2)
# Out:
#      disease_progression
# 0                  151.0
# 1                   75.0
# 2                  141.0
# 3                  206.0
# 4                  135.0
# ..                   ...
# 437                178.0
# 438                104.0
# 439                132.0
# 440                220.0
# 441                 57.0
#
# [442 rows x 1 columns]

# %%
# Merge both DataFrames to see what correlates
df = pd.merge(df1, df2, left_index=True, right_index=True)
df.describe()
# Out:
#                 age           sex           bmi            bp            tc  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                 ldl           hdl           tch           ltg           glu  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01
#
#        disease_progression
# count           442.000000
# mean            152.133484
# std              77.093005
# min              25.000000
# 25%              87.000000
# 50%             140.500000
# 75%             211.500000
# max             346.000000

# %%
# I decided to show both a heat map and scatter plot to show correlation
# As I like to see a heatmap, myself.
import matplotlib.pyplot as plt
import seaborn as sns
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, square=True, robust=True, annot=True)
# Out:
# <AxesSubplot:>

# %%
from pandas.plotting import scatter_matrix
corr = df.corr()
scatter_matrix(corr, figsize=(20,12))
# Out:
# array([[<AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='sex', ylabel='age'>,
#         <AxesSubplot:xlabel='bmi', ylabel='age'>,
#         <AxesSubplot:xlabel='bp', ylabel='age'>,
#         <AxesSubplot:xlabel='tc', ylabel='age'>,
#         <AxesSubplot:xlabel='ldl', ylabel='age'>,
#         <AxesSubplot:xlabel='hdl', ylabel='age'>,
#         <AxesSubplot:xlabel='tch', ylabel='age'>,
#         <AxesSubplot:xlabel='ltg', ylabel='age'>,
#         <AxesSubplot:xlabel='glu', ylabel='age'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='age'>],
#        [<AxesSubplot:xlabel='age', ylabel='sex'>,
#         <AxesSubplot:xlabel='sex', ylabel='sex'>,
#         <AxesSubplot:xlabel='bmi', ylabel='sex'>,
#         <AxesSubplot:xlabel='bp', ylabel='sex'>,
#         <AxesSubplot:xlabel='tc', ylabel='sex'>,
#         <AxesSubplot:xlabel='ldl', ylabel='sex'>,
#         <AxesSubplot:xlabel='hdl', ylabel='sex'>,
#         <AxesSubplot:xlabel='tch', ylabel='sex'>,
#         <AxesSubplot:xlabel='ltg', ylabel='sex'>,
#         <AxesSubplot:xlabel='glu', ylabel='sex'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='sex'>],
#        [<AxesSubplot:xlabel='age', ylabel='bmi'>,
#         <AxesSubplot:xlabel='sex', ylabel='bmi'>,
#         <AxesSubplot:xlabel='bmi', ylabel='bmi'>,
#         <AxesSubplot:xlabel='bp', ylabel='bmi'>,
#         <AxesSubplot:xlabel='tc', ylabel='bmi'>,
#         <AxesSubplot:xlabel='ldl', ylabel='bmi'>,
#         <AxesSubplot:xlabel='hdl', ylabel='bmi'>,
#         <AxesSubplot:xlabel='tch', ylabel='bmi'>,
#         <AxesSubplot:xlabel='ltg', ylabel='bmi'>,
#         <AxesSubplot:xlabel='glu', ylabel='bmi'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='bmi'>],
#        [<AxesSubplot:xlabel='age', ylabel='bp'>,
#         <AxesSubplot:xlabel='sex', ylabel='bp'>,
#         <AxesSubplot:xlabel='bmi', ylabel='bp'>,
#         <AxesSubplot:xlabel='bp', ylabel='bp'>,
#         <AxesSubplot:xlabel='tc', ylabel='bp'>,
#         <AxesSubplot:xlabel='ldl', ylabel='bp'>,
#         <AxesSubplot:xlabel='hdl', ylabel='bp'>,
#         <AxesSubplot:xlabel='tch', ylabel='bp'>,
#         <AxesSubplot:xlabel='ltg', ylabel='bp'>,
#         <AxesSubplot:xlabel='glu', ylabel='bp'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='bp'>],
#        [<AxesSubplot:xlabel='age', ylabel='tc'>,
#         <AxesSubplot:xlabel='sex', ylabel='tc'>,
#         <AxesSubplot:xlabel='bmi', ylabel='tc'>,
#         <AxesSubplot:xlabel='bp', ylabel='tc'>,
#         <AxesSubplot:xlabel='tc', ylabel='tc'>,
#         <AxesSubplot:xlabel='ldl', ylabel='tc'>,
#         <AxesSubplot:xlabel='hdl', ylabel='tc'>,
#         <AxesSubplot:xlabel='tch', ylabel='tc'>,
#         <AxesSubplot:xlabel='ltg', ylabel='tc'>,
#         <AxesSubplot:xlabel='glu', ylabel='tc'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='tc'>],
#        [<AxesSubplot:xlabel='age', ylabel='ldl'>,
#         <AxesSubplot:xlabel='sex', ylabel='ldl'>,
#         <AxesSubplot:xlabel='bmi', ylabel='ldl'>,
#         <AxesSubplot:xlabel='bp', ylabel='ldl'>,
#         <AxesSubplot:xlabel='tc', ylabel='ldl'>,
#         <AxesSubplot:xlabel='ldl', ylabel='ldl'>,
#         <AxesSubplot:xlabel='hdl', ylabel='ldl'>,
#         <AxesSubplot:xlabel='tch', ylabel='ldl'>,
#         <AxesSubplot:xlabel='ltg', ylabel='ldl'>,
#         <AxesSubplot:xlabel='glu', ylabel='ldl'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='ldl'>],
#        [<AxesSubplot:xlabel='age', ylabel='hdl'>,
#         <AxesSubplot:xlabel='sex', ylabel='hdl'>,
#         <AxesSubplot:xlabel='bmi', ylabel='hdl'>,
#         <AxesSubplot:xlabel='bp', ylabel='hdl'>,
#         <AxesSubplot:xlabel='tc', ylabel='hdl'>,
#         <AxesSubplot:xlabel='ldl', ylabel='hdl'>,
#         <AxesSubplot:xlabel='hdl', ylabel='hdl'>,
#         <AxesSubplot:xlabel='tch', ylabel='hdl'>,
#         <AxesSubplot:xlabel='ltg', ylabel='hdl'>,
#         <AxesSubplot:xlabel='glu', ylabel='hdl'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='hdl'>],
#        [<AxesSubplot:xlabel='age', ylabel='tch'>,
#         <AxesSubplot:xlabel='sex', ylabel='tch'>,
#         <AxesSubplot:xlabel='bmi', ylabel='tch'>,
#         <AxesSubplot:xlabel='bp', ylabel='tch'>,
#         <AxesSubplot:xlabel='tc', ylabel='tch'>,
#         <AxesSubplot:xlabel='ldl', ylabel='tch'>,
#         <AxesSubplot:xlabel='hdl', ylabel='tch'>,
#         <AxesSubplot:xlabel='tch', ylabel='tch'>,
#         <AxesSubplot:xlabel='ltg', ylabel='tch'>,
#         <AxesSubplot:xlabel='glu', ylabel='tch'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='tch'>],
#        [<AxesSubplot:xlabel='age', ylabel='ltg'>,
#         <AxesSubplot:xlabel='sex', ylabel='ltg'>,
#         <AxesSubplot:xlabel='bmi', ylabel='ltg'>,
#         <AxesSubplot:xlabel='bp', ylabel='ltg'>,
#         <AxesSubplot:xlabel='tc', ylabel='ltg'>,
#         <AxesSubplot:xlabel='ldl', ylabel='ltg'>,
#         <AxesSubplot:xlabel='hdl', ylabel='ltg'>,
#         <AxesSubplot:xlabel='tch', ylabel='ltg'>,
#         <AxesSubplot:xlabel='ltg', ylabel='ltg'>,
#         <AxesSubplot:xlabel='glu', ylabel='ltg'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='ltg'>],
#        [<AxesSubplot:xlabel='age', ylabel='glu'>,
#         <AxesSubplot:xlabel='sex', ylabel='glu'>,
#         <AxesSubplot:xlabel='bmi', ylabel='glu'>,
#         <AxesSubplot:xlabel='bp', ylabel='glu'>,
#         <AxesSubplot:xlabel='tc', ylabel='glu'>,
#         <AxesSubplot:xlabel='ldl', ylabel='glu'>,
#         <AxesSubplot:xlabel='hdl', ylabel='glu'>,
#         <AxesSubplot:xlabel='tch', ylabel='glu'>,
#         <AxesSubplot:xlabel='ltg', ylabel='glu'>,
#         <AxesSubplot:xlabel='glu', ylabel='glu'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='glu'>],
#        [<AxesSubplot:xlabel='age', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='sex', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='bmi', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='bp', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='tc', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='ldl', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='hdl', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='tch', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='ltg', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='glu', ylabel='disease_progression'>,
#         <AxesSubplot:xlabel='disease_progression', ylabel='disease_progression'>]],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split

# Split into validation set and training set
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=1)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((397, 10), (45, 10), (397,), (45,))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression().fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# 0.5344510439633885

# %%
pred = model.predict(X_val)
pred
# Out:
# array([122.41932407, 111.48365055, 184.18558652,  68.52087272,
#        171.44221745, 191.06463336, 220.61738089, 117.98679452,
#        156.5524466 , 126.49478122, 213.88062061, 199.98328703,
#         90.87507124,  79.36223511, 234.96537061, 204.19340103,
#        176.94030006, 101.88594035, 111.86181655, 170.60381844,
#        185.83614993,  82.11394798, 140.77629148, 106.88120017,
#         92.28592319, 212.31820792,  92.21122242, 176.92601402,
#        119.67674197, 181.00300506, 156.75743341, 138.82248129,
#        197.06334156,  98.33667675, 163.42298972, 190.93523247,
#        107.61370587, 246.79405   , 172.97198996, 186.61704933,
#        162.58918571, 180.1143173 , 118.5461696 , 121.61931807,
#        145.27196886])

# %%
from sklearn.metrics import mean_squared_error
rms = mean_squared_error(y_val, pred, squared=True)
rms
# Out:
# 3319.69258713956

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_val, pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(pred), max(y_val))
p2 = min(min(pred), min(y_val))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Actual Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.show()

# %%
plt.plot(y_val)
plt.plot(pred, 'o')
plt.show()
